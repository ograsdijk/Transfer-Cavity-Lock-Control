# %%
import h5py 
import numpy as np
import matplotlib.pyplot as plt

# %%
flname='S1.hdf5'

fig=plt.figure()
ax=fig.add_subplot(111)

with h5py.File(flname,'a') as f:
#     print(list(f.keys()))
    ax.plot(f['Time'],f['RealFrequency'])

# %%
with h5py.File(flname,'a') as f:
    print(list(f.keys()))
    for name in f:
        print(name)
